# %% [markdown]
# ## Merge and Split

# %% [markdown]
# In the previous notebook we have simulated 400k samples for each bin, the purpose of this notebook is to merge all the samples, shuffle them and split them into Train, Test and Val datasets.

# %% [markdown]
# ## Used functions

# %%
import pandas as pd
import numpy as np
import h5py
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load each dataset

# %%
d1 = pd.read_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/bin_0.parquet')

# %%
d2 = pd.read_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/bin_1.parquet')

# %%
d3 = pd.read_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/bin_2.parquet')

# %%
d4 = pd.read_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/bin_3.parquet')

# %%
d5 = pd.read_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/bin_4.parquet')

# %%
d5.head()
# Out:
#                                             Espectro      Espesor         R1  \
# 0  [1.9941862938328718e-306, 1.7735900653189752e-...  1256.235011  20.243812
# 1  [1.7338516563451103e-306, 1.545344033089083e-3...  1276.737469  34.662629
# 2  [1.78860057785471e-306, 1.5934761314119455e-30...  1245.664295  15.359553
# 3  [1.6380034700892383e-306, 1.4615167575527556e-...  1252.264494  41.977396
# 4  [1.8285873520882116e-306, 1.6317625674019585e-...  1247.371412  16.021467
#
#           R2                                          Sellmeier  \
# 0  12.983618  [3.247772813718288, 1897430.4250125375, 251787...
# 1  14.485107  [3.860168604683252, 1942278.6464520076, 116811...
# 2  39.784794  [3.2464647225181706, 1807590.9761237241, 99683...
# 3  34.558859  [3.2484722891857514, 2207820.1139675733, 34760...
# 4  12.250753  [3.2524417216098565, 1743563.8286596972, 21736...
#
#                                            Absorcion            ne
# 0  [0.009079422484865297, 9.95691213018204, 345.8...  7.457124e+25
# 1  [0.008340324550883876, 8.559652536511406, 356....  2.059097e+26
# 2  [0.00626019177230651, 9.271007455923444, 349.5...  1.261858e+26
# 3  [0.004799245612907399, 9.775241773871734, 348....  2.111784e+26
# 4  [0.007590051812570198, 8.533042376884568, 358....  1.075518e+26

# %%
df_final = pd.concat([d1, d2, d3, d4, d5], ignore_index=True)

# %%
df_final.shape
# Out:
# (1200000, 7)

# %%
df_final = df_final.sample(frac=1).reset_index(drop=True)

# %%
df_final.head(15)
# Out:
#                                              Espectro      Espesor         R1  \
# 0   [1.833396585131492e-306, 1.632502257416434e-30...  1010.225333  29.544133
# 1   [1.762743398566019e-306, 1.5733289916818208e-3...   360.934149   7.397823
# 2   [1.9853046158252384e-306, 1.7658511566147705e-...   157.320777   5.938790
# 3   [1.2547675824941182e-306, 1.123605893186129e-3...   236.116942  36.739007
# 12  [0.00911459308909675, 9.200139808646734, 363.5...  1.655197e+26
# 13  [0.012228652739601272, 8.643583313484848, 363....  1.082234e+26
# 14  [0.0006261968639420393, 10.504525436264347, 36...  5.078839e+25

# %%
df_final.to_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/Final_Dataset.parquet')

# %% [markdown]
# ## Convert the Final DF into Train Test Val in h5

# %%
df_final = pd.read_parquet('/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/Final_Dataset.parquet')

# %%
x = df_final['Espectro']
n, m = x.shape[0], len(x[0])
x = np.concatenate(x)
x = x.reshape(n, m, 1) # Organizamos la informacion de manera conveniente
x.shape
# Out:
# (1200000, 911, 1)

# %%
y = np.array(df_final['Espesor'], dtype = np.float32)
y = y.reshape(-1, 1) # Los datos deben ser de la forma (n, 1)
y.shape
# Out:
# (1200000, 1)

# %%
def data_to_TrainTestVal(data:list, folder_path:str, p_train: float = 0.95, p_test: float = 0.04,  )-> None:
    '''
    Description:
        This functions converts a unique h5 file containing all the data into multiples set: train, test y val
        according to the proportions given in the args. It save all the files in a given folder.

    Args:
        file_path (str): Path to the h5 data
        folder_path (str): Folder path where the data will be saved
        p_train (float): Data porcentage to be used for train
        p_test (float): Data porcentage to be used for test

    Returns:
        None
    '''

    x_data = data[0]
    y_data = data[1]

    x_train, y_train = x_data[ : int( x_data.shape[0] * p_train) ], y_data[ : int( y_data.shape[0] * p_train) ]

    x_test, y_test = x_data[int( x_data.shape[0] * p_train) :int( x_data.shape[0] * (p_train + p_test) ) ], y_data[int( y_data.shape[0] * p_train) :int( y_data.shape[0] * (p_train + p_test) ) ]

    x_val, y_val =  x_data[int( x_data.shape[0] * (p_train + p_test) ) : ], y_data[int( y_data.shape[0] * (p_train + p_test) ) : ]

    to_h5(x = x_train, y = y_train, file_name = folder_path + '/train.h5')
    to_h5(x = x_test, y = y_test, file_name = folder_path + '/test.h5')
    to_h5(x = x_val, y = y_val, file_name = folder_path + '/val.h5')

    print('Done!')

# %%
def to_h5(x, y, file_name):

    if not os.path.exists(file_name): # Verifica que la ruta no exista
        f = h5py.File(file_name, 'w') # Crea la ruta
        f.create_dataset('x_total', data = x, chunks=True, maxshape=(None, x.shape[1], x.shape[2]) )
        f.create_dataset('y_total', data = y, chunks=True, maxshape=(None, y.shape[1]) )
        print(f.keys())
        f.close()

# %%
data_to_TrainTestVal([x, y],
                     folder_path = '/content/drive/MyDrive/AzONet/notebooks/3_data_simulation/NewDataAzONetV2/Sets',
                     p_train = 0.80,
                     p_test = 0.1)
# Out:
# <KeysViewHDF5 ['x_total', 'y_total']>
# <KeysViewHDF5 ['x_total', 'y_total']>
# <KeysViewHDF5 ['x_total', 'y_total']>
# Done!
