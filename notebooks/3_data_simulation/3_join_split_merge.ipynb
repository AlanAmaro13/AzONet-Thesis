# %% [markdown]
# ## Merge and Split

# %% [markdown]
# In the previous notebook we have simulated 400k samples for each bin, the purpose of this notebook is to merge all the samples, shuffle them and split them into Train, Test and Val datasets.

# %% [markdown]
# ## Used functions

# %%
import pandas as pd
import numpy as np
import h5py
import os

# %% [markdown]
# ## Load each dataset

# %%
d1 = pd.read_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/bin_0.parquet')

# %%
d2 = pd.read_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/bin_1.parquet')

# %%
d3 = pd.read_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/bin_2.parquet')

# %%
d4 = pd.read_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/bin_3.parquet')

# %%
d5 = pd.read_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/bin_4.parquet')

# %%
d5.head()
# Out:
#                                             Espectro      Espesor         R1  \
# 0  [1.8384000011402496e-306, 1.636974420935395e-3...  1356.725436  18.096532
# 1  [9.23287146321795e-307, 8.393609326984373e-307...  1231.782574  38.297464
# 2  [1.7412772595582437e-306, 1.551702201243842e-3...  1217.268520  35.615512
# 3  [1.8431284546156588e-306, 1.6418493422429746e-...  1136.275069  18.203075
# 4  [1.706043474008625e-306, 1.520969797598473e-30...  1267.314913  30.097252
#
#           R2                                          Sellmeier  \
# 0  32.515092  [3.2574904515425707, 2053209.6453125672, 24627...
# 1  36.942630  [3.271107032509617, 1793905.8613346543, 251542...
# 2  26.056852  [3.2831534768494546, 2188714.96618508, 2777399...
# 3  35.562478  [3.2788825141807614, 1979065.9211040877, 28657...
# 4  33.016867  [3.479721495836185, 1293712.9114847793, 807233...
#
#                                            Absorcion            ne
# 0  [0.011231054928953, 8.860378157038712, 351.305...  1.481506e+26
# 1  [0.0075436199389320386, 9.4597368286169, 344.8...  1.090880e+26
# 2  [0.0057555501292843, 8.960912770490193, 346.32...  1.207449e+26
# 3  [0.005429777618544704, 9.39727203120356, 358.0...  8.753841e+25
# 4  [0.010391787807184168, 9.364360989696172, 346....  1.809490e+26

# %%
df_final = pd.concat([d1, d2, d3, d4, d5], ignore_index=True)

# %%
df_final.shape
# Out:
# (1200000, 7)

# %%
df_final = df_final.sample(frac=1).reset_index(drop=True)

# %%
df_final.head(15)
# Out:
#                                              Espectro      Espesor         R1  \
# 0   [2.011619763476001e-306, 1.788917746282114e-30...  1032.149758  19.745526
# 1   [1.717502602851602e-306, 1.531828505108551e-30...  1012.292227  29.384435
# 2   [1.8680746944154086e-306, 1.6633650567549047e-...  1191.534289  24.426309
# 3   [1.9731345439442655e-306, 1.755262518430366e-3...  1046.266494  25.048139
# 4   [1.948555979859996e-306, 1.73368357941414e-306...  1344.318622  21.166685
# 12  [0.0039528491612188, 10.180638302106047, 354.2...  7.497209e+26
# 13  [0.008291882935318014, 10.511047157469847, 372...  2.871770e+26
# 14  [0.010028467671903078, 9.54137861122424, 361.4...  6.547171e+25

# %%
df_final.to_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/Final_Dataset.parquet')

# %% [markdown]
# ## Convert the Final DF into Train Test Val in h5

# %%
df_final = pd.read_parquet('/home/alan-amaro/Documents/Thesis_New_Data/DataBins/Final_Dataset.parquet')

# %%
x = df_final['Espectro'] 
n, m = x.shape[0], len(x[0])
x = np.concatenate(x) 
x = x.reshape(n, m, 1) # Organizamos la informacion de manera conveniente
x.shape
# Out:
# (1200000, 911, 1)

# %%
y = np.array(df_final['Espesor'], dtype = np.float32)
y = y.reshape(-1, 1) # Los datos deben ser de la forma (n, 1)
y.shape
# Out:
# (1200000, 1)

# %%
def data_to_TrainTestVal(data:list, folder_path:str, p_train: float = 0.95, p_test: float = 0.04,  )-> None:
    '''
    Description:
        This functions converts a unique h5 file containing all the data into multiples set: train, test y val 
        according to the proportions given in the args. It save all the files in a given folder. 

    Args:
        file_path (str): Path to the h5 data
        folder_path (str): Folder path where the data will be saved
        p_train (float): Data porcentage to be used for train 
        p_test (float): Data porcentage to be used for test

    Returns: 
        None
    ''' 
    
    x_data = data[0]
    y_data = data[1]

    x_train, y_train = x_data[ : int( x_data.shape[0] * p_train) ], y_data[ : int( y_data.shape[0] * p_train) ]

    x_test, y_test = x_data[int( x_data.shape[0] * p_train) :int( x_data.shape[0] * (p_train + p_test) ) ], y_data[int( y_data.shape[0] * p_train) :int( y_data.shape[0] * (p_train + p_test) ) ] 

    x_val, y_val =  x_data[int( x_data.shape[0] * (p_train + p_test) ) : ], y_data[int( y_data.shape[0] * (p_train + p_test) ) : ] 

    to_h5(x = x_train, y = y_train, file_name = folder_path + '/train.h5') 
    to_h5(x = x_test, y = y_test, file_name = folder_path + '/test.h5')
    to_h5(x = x_val, y = y_val, file_name = folder_path + '/val.h5')

    print('Done!')

# %%
def to_h5(x, y, file_name):

    if not os.path.exists(file_name): # Verifica que la ruta no exista
        f = h5py.File(file_name, 'w') # Crea la ruta
        f.create_dataset('x_total', data = x, chunks=True, maxshape=(None, x.shape[1], x.shape[2]) )
        f.create_dataset('y_total', data = y, chunks=True, maxshape=(None, y.shape[1]) )
        print(f.keys())
        f.close()

# %%
data_to_TrainTestVal([x, y], 
                     folder_path = '/home/alan-amaro/Documents/Thesis_New_Data/Sets/',
                     p_train = 0.90, 
                     p_test = 0.09,)
# Out:
# <KeysViewHDF5 ['x_total', 'y_total']>
# <KeysViewHDF5 ['x_total', 'y_total']>
# <KeysViewHDF5 ['x_total', 'y_total']>
# Done!
